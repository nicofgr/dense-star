# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import AutoMinorLocator, MultipleLocator

plt.rcParams['text.usetex'] = True

fig, ax1 = plt.subplots(2,2)
#-------------------------------------------------------
bagPressures = []
bagPressures.append(145)
bagPressures.append(155)
bagPressures.append(165)
bagPressures.append(175)
titles = []
titles.append('ud')
titles.append('uds')
titles.append('udsc')
titles.append('udscb')
titles.append('udscbt')
dirs = []
for bP in bagPressures:
    for i in titles:
        dirs.append('../cpp/output/' + i + 'B' + str(bP) +'.dat')
#print(dirs)
cols = []
cols.append('b')
cols.append('g-.')
cols.append('c--')
cols.append('r:')
cols.append('m')

for j in range(2):
    for k in range(2):
        x = []
        ax1[j,k].set_title("Pressão e massa versus raio para B="+ str(bagPressures[k+2*j]) +"MeV")
        ax1[j,k].set_xlabel(r'$r$ (km)')
        ax1[j,k].set_ylabel(r'$p$ (MeV/f$m^3$)')
        ax1[j,k].set_xlim([0,12.5])
        ax1[j,k].xaxis.set_major_locator(MultipleLocator(2))
        ax1[j,k].xaxis.set_minor_locator(MultipleLocator(1))
        ax1[j,k].yaxis.set_major_locator(MultipleLocator(50))
        ax1[j,k].yaxis.set_minor_locator(MultipleLocator(25))
        ax1[j,k].set_ylim([0,250])
        ax2 = ax1[j,k].twinx()
        ax2.set_ylabel(r'$m/M_\odot$')
        ax2.set_ylim([0,2.5])
        ax2.yaxis.set_major_locator(MultipleLocator(0.5))
        ax2.yaxis.set_minor_locator(MultipleLocator(0.25))
        
        for i in range(5):
            x.append([])
            with open(dirs[i+k*5+j*10], 'r') as f:   
                #print(dirs[i+k*5+j*10])
                lines = f.readlines()
                x[i].append([float(line.split()[0]) for line in lines])
                x[i].append([float(line.split()[1]) for line in lines])
                x[i].append([float(line.split()[2]) for line in lines])

            ax1[j,k].grid()
            ax1[j,k].plot(x[i][0],x[i][1], cols[i], label=titles[i])
            ax2.plot(x[i][0],x[i][2], cols[i])
        
        ax1[j,k].legend(loc='upper center')
plt.rcParams['figure.figsize'] = [15, 10]
plt.rcParams['figure.dpi'] = 300
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import AutoMinorLocator, MultipleLocator

plt.rcParams['text.usetex'] = True
plt.rcParams["font.size"] = 10

fig, ax1 = plt.subplots(1,2)
#-------------------------------------------------------
bagPressures = []
bagPressures.append(145)
bagPressures.append(175)
titles = []
titles.append('ud')
titles.append('uds')
titles.append('udsc')
titles.append('udscb')
titles.append('udscbt')
dirs = []
for bP in bagPressures:
    for i in titles:
        dirs.append('../cpp/output/' + i + 'B' + str(bP) +'.dat')
#print(dirs)
cols = []
cols.append('b')
cols.append('g-.')
cols.append('c--')
cols.append('r:')
cols.append('m')

for k in range(2):
    x = []
    ax1[k].set_title("Pressão e massa versus raio para B="+ str(bagPressures[k]) +"MeV")
    ax1[k].set_xlabel(r'$r$ (km)')
    ax1[k].set_ylabel(r'$p$ (MeV/f$m^3$)')
    ax1[k].set_xlim([0,12.5])
    ax1[k].xaxis.set_major_locator(MultipleLocator(2))
    ax1[k].xaxis.set_minor_locator(MultipleLocator(1))
    ax1[k].yaxis.set_major_locator(MultipleLocator(50))
    ax1[k].yaxis.set_minor_locator(MultipleLocator(25))
    ax1[k].set_ylim([0,250])
    ax2 = ax1[k].twinx()
    ax2.set_ylabel(r'$m/M_\odot$')
    ax2.set_ylim([0,2.5])
    ax2.yaxis.set_major_locator(MultipleLocator(0.5))
    ax2.yaxis.set_minor_locator(MultipleLocator(0.25))
        
    for i in range(5):
        x.append([])
        with open(dirs[i+k*5], 'r') as f:   
            #print(dirs[i+k*5+j*10])
            lines = f.readlines()
            x[i].append([float(line.split()[0]) for line in lines])
            x[i].append([float(line.split()[1]) for line in lines])
            x[i].append([float(line.split()[2]) for line in lines])

        ax1[k].grid()
        ax1[k].plot(x[i][0],x[i][1], cols[i], label=titles[i])
        ax2.plot(x[i][0],x[i][2], cols[i])
        
    ax1[k].legend(loc='upper center')
plt.rcParams['figure.figsize'] = [9, 4]
plt.rcParams['figure.dpi'] = 300
fig.tight_layout(pad=2.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import AutoMinorLocator, MultipleLocator

plt.rcParams['text.usetex'] = True
plt.rcParams["font.size"] = 12
plt.rcParams['figure.figsize'] = [11, 7]
plt.rcParams['figure.dpi'] = 300

fig, ax1 = plt.subplots(2,3)
#-------------------------------------------------------
bagPressures = []
bagPressures.append(145)
#bagPressures.append(155)
#bagPressures.append(165)
bagPressures.append(175)
titles = []
titles.append('ud')
titles.append('uds')
titles.append('udsc')
titles.append('udscb')
titles.append('udscbt')
dirs = []
for bP in bagPressures:
    for i in titles:
        dirs.append('../cpp/output/' + i + 'B' + str(bP) +'.dat')
print(dirs)
cols = []
cols.append('b')
cols.append('g-.')
cols.append('c--')
cols.append('r:')
cols.append('m')

for j in range(2):
    for k in range(3):
        if (k+j*2 == 4): break
        x = []
        ax1[j,k].set_title(titles[k+j*3])
        ax1[j,k].set_xlabel(r'$\epsilon$ (MeV/fm$^3$)')
        ax1[j,k].set_ylabel(r'$p$ (MeV/f$m^3$)')
        ax1[j,k].set_xlim([0,1000])
        #ax1[j,k].xaxis.set_major_locator(MultipleLocator(2))
        #ax1[j,k].xaxis.set_minor_locator(MultipleLocator(1))
        ax1[j,k].set_ylim([0,220])
        
        for i in range(len(bagPressures)):
            x.append([])
            with open(dirs[(i*5)+k+(3*j)], 'r') as f:   
                
                lines = f.readlines()
                x[i].append([float(line.split()[0]) for line in lines])
                x[i].append([float(line.split()[1]) for line in lines])
                x[i].append([float(line.split()[2]) for line in lines])
                x[i].append([float(line.split()[3]) for line in lines])

                ax1[j,k].grid(True)
                ax1[j,k].plot(x[i][3],x[i][1], cols[i], label="B="+str(bagPressures[i])+"MeV")
                print(dirs[i*5], "|| Color: ", cols[i], "|| Graph: [", j,",",k,"]")
        
        ax1[j,k].legend(loc='upper left')
fig.suptitle("Pressão versus densidade de energia para diferentes combinações de quarks")
fig.delaxes(ax1[1,2])
fig.tight_layout(pad=1.25)
plt.show()
# Out:
# ['../cpp/output/udB145.dat', '../cpp/output/udsB145.dat', '../cpp/output/udscB145.dat', '../cpp/output/udscbB145.dat', '../cpp/output/udscbtB145.dat', '../cpp/output/udB175.dat', '../cpp/output/udsB175.dat', '../cpp/output/udscB175.dat', '../cpp/output/udscbB175.dat', '../cpp/output/udscbtB175.dat']
# ../cpp/output/udB145.dat || Color:  b || Graph: [ 0 , 0 ]
# ../cpp/output/udB175.dat || Color:  g-. || Graph: [ 0 , 0 ]
# ../cpp/output/udB145.dat || Color:  b || Graph: [ 0 , 1 ]
# ../cpp/output/udB175.dat || Color:  g-. || Graph: [ 0 , 1 ]
# ../cpp/output/udB145.dat || Color:  b || Graph: [ 0 , 2 ]
# ../cpp/output/udB175.dat || Color:  g-. || Graph: [ 0 , 2 ]
# ../cpp/output/udB145.dat || Color:  b || Graph: [ 1 , 0 ]
# ../cpp/output/udB175.dat || Color:  g-. || Graph: [ 1 , 0 ]
# ../cpp/output/udB145.dat || Color:  b || Graph: [ 1 , 1 ]
# ../cpp/output/udB175.dat || Color:  g-. || Graph: [ 1 , 1 ]

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import AutoMinorLocator, MultipleLocator

plt.rcParams['text.usetex'] = True
plt.rcParams["font.size"] = 12
plt.rcParams['figure.figsize'] = [11, 7]
plt.rcParams['figure.dpi'] = 300

fig, ax1 = plt.subplots(2,3)
#-------------------------------------------------------
bagPressures = []
bagPressures.append(145)
#bagPressures.append(155)
#bagPressures.append(165)
bagPressures.append(175)
titles = []
titles.append('ud')
titles.append('uds')
titles.append('udsc')
titles.append('udscb')
titles.append('udscbt')
dirs = []
for bP in bagPressures:
    for i in titles:
        dirs.append('../cpp/output/P3' + i + str(bP) +'.dat')
print(dirs)
cols = []
cols.append('b')
cols.append('g-.')
cols.append('c--')
cols.append('r:')
cols.append('m')

for j in range(2):
    for k in range(3):
        if (k+j*2 == 4): break
        x = []
        ax1[j,k].set_title(titles[k+j*3])
        ax1[j,k].set_xlabel(r'$p_0$ (MeV/f$m^3$)')
        ax1[j,k].set_ylabel(r'$M/M_\odot$')
        ax1[j,k].set_xlim([0, 650])
        #ax1[j,k].xaxis.set_major_locator(MultipleLocator(2))
        ax1[j,k].xaxis.set_minor_locator(MultipleLocator(100))
        ax1[j,k].set_ylim([1,2.5])
        
        for i in range(len(bagPressures)):
            x.append([])
            with open(dirs[(i*5)+k+(3*j)], 'r') as f:   
                
                lines = f.readlines()
                x[i].append([float(line.split()[0]) for line in lines])
                x[i].append([float(line.split()[1]) for line in lines])
                x[i].append([float(line.split()[2]) for line in lines])

                ax1[j,k].grid(True)
                ax1[j,k].plot(x[i][1],x[i][2], cols[i], label="B="+str(bagPressures[i])+"MeV")
                print(dirs[(i*5)+k+(3*j)], "|| Color: ", cols[i], "|| Graph: [", j,",",k,"]")
        
        ax1[j,k].legend(loc='lower right')
        
fig.suptitle("Massa versus pressão central para densidade central entre $2n_0$ e $10n_0$ e diferentes combinações de quarks")
fig.delaxes(ax1[1,2])
fig.tight_layout(pad=1.25)
plt.show()
# Out:
# ['../cpp/output/P3ud145.dat', '../cpp/output/P3uds145.dat', '../cpp/output/P3udsc145.dat', '../cpp/output/P3udscb145.dat', '../cpp/output/P3udscbt145.dat', '../cpp/output/P3ud175.dat', '../cpp/output/P3uds175.dat', '../cpp/output/P3udsc175.dat', '../cpp/output/P3udscb175.dat', '../cpp/output/P3udscbt175.dat']
# ../cpp/output/P3ud145.dat || Color:  b || Graph: [ 0 , 0 ]
# ../cpp/output/P3ud175.dat || Color:  g-. || Graph: [ 0 , 0 ]
# ../cpp/output/P3uds145.dat || Color:  b || Graph: [ 0 , 1 ]
# ../cpp/output/P3uds175.dat || Color:  g-. || Graph: [ 0 , 1 ]
# ../cpp/output/P3udsc145.dat || Color:  b || Graph: [ 0 , 2 ]
# ../cpp/output/P3udsc175.dat || Color:  g-. || Graph: [ 0 , 2 ]
# ../cpp/output/P3udscb145.dat || Color:  b || Graph: [ 1 , 0 ]
# ../cpp/output/P3udscb175.dat || Color:  g-. || Graph: [ 1 , 0 ]
# ../cpp/output/P3udscbt145.dat || Color:  b || Graph: [ 1 , 1 ]
# ../cpp/output/P3udscbt175.dat || Color:  g-. || Graph: [ 1 , 1 ]

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import AutoMinorLocator, MultipleLocator

plt.rcParams['text.usetex'] = True
plt.rcParams["font.size"] = 12
plt.rcParams['figure.figsize'] = [11, 7]
plt.rcParams['figure.dpi'] = 300

fig, ax1 = plt.subplots(2,3)
#-------------------------------------------------------
bagPressures = []
bagPressures.append(145)
#bagPressures.append(155)
#bagPressures.append(165)
bagPressures.append(175)
titles = []
titles.append('ud')
titles.append('uds')
titles.append('udsc')
titles.append('udscb')
titles.append('udscbt')
dirs = []
for bP in bagPressures:
    for i in titles:
        dirs.append('../cpp/output/P3' + i + str(bP) +'.dat')
print(dirs)
cols = []
cols.append('b')
cols.append('g-.')
cols.append('c--')
cols.append('r:')
cols.append('m')

for j in range(2):
    for k in range(3):
        if (k+j*2 == 4): break
        x = []
        ax1[j,k].set_title(titles[k+j*3])
        ax1[j,k].set_xlabel(r'$R$ (km)')
        ax1[j,k].set_ylabel(r'$M/M_\odot$')
        ax1[j,k].set_xlim([6, 13])
        #ax1[j,k].xaxis.set_major_locator(MultipleLocator(2))
        ax1[j,k].xaxis.set_minor_locator(MultipleLocator(1))
        ax1[j,k].set_ylim([1,2.5])
        
        for i in range(len(bagPressures)):
            x.append([])
            with open(dirs[(i*5)+k+(3*j)], 'r') as f:   
                
                lines = f.readlines()
                x[i].append([float(line.split()[0]) for line in lines])
                x[i].append([float(line.split()[1]) for line in lines])
                x[i].append([float(line.split()[2]) for line in lines])

                ax1[j,k].grid(True)
                ax1[j,k].plot(x[i][0],x[i][2], cols[i], label="B="+str(bagPressures[i])+"MeV")
                print(dirs[(i*5)+k+(3*j)], "|| Color: ", cols[i], "|| Graph: [", j,",",k,"]")
        
        ax1[j,k].legend(loc='upper left')
fig.delaxes(ax1[1,2])
fig.suptitle("Massa versus raio para densidades centrais entre $2n_0$ e $10n_0$ e diferentes combinações de quarks")

fig.tight_layout(pad=1.25)
plt.show()
# Out:
# ['../cpp/output/P3ud145.dat', '../cpp/output/P3uds145.dat', '../cpp/output/P3udsc145.dat', '../cpp/output/P3udscb145.dat', '../cpp/output/P3udscbt145.dat', '../cpp/output/P3ud175.dat', '../cpp/output/P3uds175.dat', '../cpp/output/P3udsc175.dat', '../cpp/output/P3udscb175.dat', '../cpp/output/P3udscbt175.dat']
# ../cpp/output/P3ud145.dat || Color:  b || Graph: [ 0 , 0 ]
# ../cpp/output/P3ud175.dat || Color:  g-. || Graph: [ 0 , 0 ]
# ../cpp/output/P3uds145.dat || Color:  b || Graph: [ 0 , 1 ]
# ../cpp/output/P3uds175.dat || Color:  g-. || Graph: [ 0 , 1 ]
# ../cpp/output/P3udsc145.dat || Color:  b || Graph: [ 0 , 2 ]
# ../cpp/output/P3udsc175.dat || Color:  g-. || Graph: [ 0 , 2 ]
# ../cpp/output/P3udscb145.dat || Color:  b || Graph: [ 1 , 0 ]
# ../cpp/output/P3udscb175.dat || Color:  g-. || Graph: [ 1 , 0 ]
# ../cpp/output/P3udscbt145.dat || Color:  b || Graph: [ 1 , 1 ]
# ../cpp/output/P3udscbt175.dat || Color:  g-. || Graph: [ 1 , 1 ]
